# %%
import os
import tarfile
import xml.etree.ElementTree as ET
from sets import Set
s= Set([])

# Set the directory you want to start from
rootDir = 'data0'
for dirName, subdirList, fileList in os.walk(rootDir):
    for fname in fileList:
        dict = {}
        guid = fname[:-4]
        pdate = dirName[6:]
        orgs = ''
        headline = ''
        body = ''
        
        tree = ET.parse(dirName + '/' + fname)
        for meta in tree.getroot().iter('meta'):
            if not meta.get('name') == '':
                dict[meta.get('name')] = meta.get('content')
        for classifier in tree.getroot().iter('classifier'):
            if not classifier.get('type') == '':
                dict[classifier.get('type')] = classifier.text
        for byline in tree.getroot().iter('byline'):
            if byline.get('class') == 'normalized_byline':
                dict['normalized_byline'] = byline.text
        for org in tree.getroot().iter('byline'):
            orgs = orgs + ', ' + org.text
    
        for body in tree.getroot().iter('body.content'):
            body = body.text
        
        for headline in tree.getroot().iter('headline'):
            headline = body.text
        orgs = orgs[2:]
        print guid
        print pdate
        print orgs
        #print body
        #print headline
        print dict
        print
# Out:
# 1729018
# 2006/01/01
# By Dave Anderson, Anderson, Dave
# {'taxonomic_classifier': 'Top/News/Sports/Baseball', 'descriptor': 'Baseball', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Baseball', 'dsk': 'Sports Desk', 'print_page_number': '9', 'normalized_byline': 'Anderson, Dave', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01andebase'}
#
# 1729019
# 2006/01/01
# By Dave Anderson, Anderson, Dave
# {'taxonomic_classifier': 'Top/News/Sports/Pro Football', 'descriptor': 'Football', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Football', 'dsk': 'Sports Desk', 'print_page_number': '9', 'normalized_byline': 'Anderson, Dave', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01andefoot'}
#
# 1729020
# 2006/01/01
# By Dave Andeson
# {'taxonomic_classifier': 'Top/News/Sports/Other Sports', 'descriptor': 'Athletics and Sports', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Athletics and Sports', 'dsk': 'Sports Desk', 'print_page_number': '9', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01andehock'}
#
# 1729021
# 2006/01/01
# By JASON DIAMOS, Diamos, Jason
# {'taxonomic_classifier': 'Top/News/Sports/Hockey', 'descriptor': 'Hockey, Ice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Hockey, Ice', 'dsk': 'Sports Desk', 'print_page_number': '8', 'normalized_byline': 'Diamos, Jason', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01rangers'}
#
# 1729022
# 2006/01/01
# By LYNN ZINSER and WINA STURGEON, Sturgeon, Wina; Zinser, Lynn
# {'taxonomic_classifier': 'Top/News/Sports/Olympics 2006/Skeleton', 'descriptor': 'Skeleton (Sport)', 'publication_day_of_month': '1', 'normalized_byline': 'Sturgeon, Wina; Zinser, Lynn', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Coaches and Managers', 'dsk': 'Sports Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/sports/othersports/01skeleton.html', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01skeleton'}
#
# 1729023
# 2006/01/01
# By ALEX BERENSON, Berenson, Alex
# {'taxonomic_classifier': 'Top/News/Health/Diseases, Conditions, and Health Topics/Drugs (Pharmaceuticals)/Antidepressants', 'descriptor': 'Suicides and Suicide Attempts', 'publication_day_of_month': '1', 'normalized_byline': 'Berenson, Alex', 'publication_year': '2006', 'online_sections': 'Health; U.S.', 'publication_month': '1', 'general_descriptor': 'Medicine and Health', 'dsk': 'National Desk', 'print_page_number': '15', 'alternate_url': 'http://www.nytimes.com/2006/01/01/health/01depress.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01depress'}
#
# 1729024
# 2006/01/01
# By ROBERT PEAR and MILT FREUDENHEIM, Freudenheim, Milt; Pear, Robert
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States', 'descriptor': 'Aged', 'publication_day_of_month': '1', 'normalized_byline': 'Freudenheim, Milt; Pear, Robert', 'publication_year': '2006', 'online_sections': 'Health; U.S.', 'publication_month': '1', 'general_descriptor': 'Medicine and Health', 'dsk': 'National Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/national/01drug.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01drug'}
#
# 1729025
# 2006/01/01
# By DAVID KOCIENIEWSKI
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/New Jersey', 'feature_page': 'Second Front', 'types_of_material': 'Series', 'publication_day_of_month': '1', 'series_name': 'POWER BROKERS: Getting It Built', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Metropolitan Desk', 'print_page_number': '19', 'alternate_url': 'http://www.nytimes.com/2006/01/01/nyregion/01lynch.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01lynch'}
#
# 1729026
# 2006/01/01
# By GINGER THOMPSON, Thompson, Ginger
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Central and South America/Guatemala', 'descriptor': 'Violence', 'publication_day_of_month': '1', 'normalized_byline': 'Thompson, Ginger', 'publication_year': '2006', 'online_sections': 'World', 'publication_month': '1', 'general_descriptor': 'Children and Youth', 'correction_date': '20060104T000000', 'dsk': 'Foreign Desk', 'print_page_number': '10', 'alternate_url': 'http://www.nytimes.com/2006/01/01/international/01guatemala.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'banner': 'CORRECTION APPENDED', 'slug': '01guatemala'}
#
# 1729027
# 2006/01/01
# By WARREN HOGE, Hoge, Warren
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Caribbean and Bermuda/Cuba', 'descriptor': 'International Relations', 'publication_day_of_month': '1', 'normalized_byline': 'Hoge, Warren', 'publication_year': '2006', 'online_sections': 'World', 'publication_month': '1', 'general_descriptor': 'Politics and Government', 'dsk': 'Foreign Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/international/01nations.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': '01nations'}
#
# 1729028
# 2006/01/01
# By C. J. CHIVERS, Chivers, C J
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Europe/Russia', 'descriptor': 'Gas (Fuel)', 'publication_day_of_month': '1', 'normalized_byline': 'Chivers, C J', 'publication_year': '2006', 'online_sections': 'World', 'publication_month': '1', 'general_descriptor': 'Politics and Government', 'dsk': 'Foreign Desk', 'print_page_number': '6', 'alternate_url': 'http://www.nytimes.com/2006/01/01/international/europe/01russia.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01russia'}
#
# 1729029
# 2006/01/01
# By The New York Times
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Middle East/Lebanon', 'descriptor': 'Politics and Government', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'World', 'publication_month': '1', 'general_descriptor': 'Politics and Government', 'dsk': 'Foreign Desk', 'print_page_number': '6', 'alternate_url': 'http://www.nytimes.com/2006/01/01/international/middleeast/01syria.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01syria'}
#
# 1729030
# 2006/01/01
# By NEIL GENZLINGER
# {'publication_day_of_month': '1', 'publication_year': '2006', 'publication_month': '1', 'dsk': 'Television', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/arts/television/01tv-cover.html', 'print_section': '13', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '0101cover'}
#
# 1729031
# 2006/01/01
# By Anita Gates
# {'descriptor': 'NO INDEX TERMS FROM NYTIMES', 'publication_day_of_month': '1', 'publication_year': '2006', 'publication_month': '1', 'dsk': 'Television', 'print_page_number': '5', 'alternate_url': 'http://www.nytimes.com/2006/01/01/arts/television/01tv-movies.html', 'print_section': '13', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '0101critic'}
#
# 1729032
# 2006/01/01
# By DAVE CALDWELL, Caldwell, Dave
# {'taxonomic_classifier': 'Top/News/Sports/College Basketball', 'descriptor': 'Basketball', 'publication_day_of_month': '1', 'normalized_byline': 'Caldwell, Dave', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'College Athletics', 'dsk': 'Sports Desk', 'print_page_number': '3', 'alternate_url': 'http://www.nytimes.com/2006/01/01/sports/ncaabasketball/01iona.html', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01iona'}
#
# 1729033
# 2006/01/01
# By BILL FINLEY, Finley, Bill
# {'taxonomic_classifier': 'Top/News/Sports/College Basketball', 'descriptor': 'Basketball', 'publication_day_of_month': '1', 'normalized_byline': 'Finley, Bill', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'College Athletics', 'dsk': 'Sports Desk', 'print_page_number': '3', 'alternate_url': 'http://www.nytimes.com/2006/01/01/sports/ncaabasketball/01rutgers.html', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01rutgers'}
#
# 1729034
# 2006/01/01
# By DAVID LEONHARDT, Leonhardt, David
# {'taxonomic_classifier': 'Top/News/Sports/Pro Football', 'descriptor': 'Playoff Games', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Baseball', 'dsk': 'Sports Desk', 'print_page_number': '5', 'normalized_byline': 'Leonhardt, David', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01score'}
#
# 1729035
# 2006/01/01
# By JAMES G. COBB
# {'taxonomic_classifier': 'Top/Classifieds/Automobiles', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Automobiles', 'publication_month': '1', 'dsk': 'Automobiles', 'print_page_number': '1', 'print_section': '12', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01AUTO'}
#
# 1729036
# 2006/01/01
# By JAMES G. COBB
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Activities and Interests/Eco-tourism', 'descriptor': 'Environment', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Automobiles', 'publication_month': '1', 'general_descriptor': 'Automobiles', 'dsk': 'Automobiles', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/automobiles/01GREEN.html', 'print_section': '12', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01GREEN'}
#
# 1729037
# 2006/01/01
# By TANYA MOHN
# {'taxonomic_classifier': 'Top/News/Education', 'descriptor': 'Executives and Management', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Education; Job Market', 'publication_month': '1', 'general_descriptor': 'Education and Schools', 'dsk': 'Job Market', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/jobs/01jmar.html', 'print_section': '10', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01jmar'}
#
# 1729038
# 2006/01/01
# By Lisa Belkin
# {'taxonomic_classifier': 'Top/News/Health/Diseases, Conditions, and Health Topics/Transplants', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Job Market', 'publication_month': '1', 'dsk': 'Job Market', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/jobs/01wcol.html', 'print_section': '10', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01wcol'}
#
# 1729039
# 2006/01/01
# By THOMAS VINCIGUERRA
# {'taxonomic_classifier': 'Top/Features/Week in Review', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Week in Review', 'publication_month': '1', 'dsk': 'Week in Review Desk', 'print_page_number': '5', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01word.ready.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01word'}
#
# 1729040
# 2006/01/01
# By JOE LAPOINTE, Lapointe, Joe
# {'taxonomic_classifier': 'Top/News/Sports/Pro Football/National Football League', 'descriptor': 'Football', 'publication_day_of_month': '1', 'normalized_byline': 'Lapointe, Joe', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Football', 'dsk': 'Sports Desk', 'print_page_number': '7', 'alternate_url': 'http://www.nytimes.com/2006/01/01/sports/football/01blue.html', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01blue'}
#
# 1729041
# 2006/01/01
# By JOHN BRANCH, Branch, John
# {'taxonomic_classifier': 'Top/News/Sports/Pro Football', 'descriptor': 'Football', 'publication_day_of_month': '1', 'normalized_byline': 'Branch, John', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Baseball', 'dsk': 'Sports Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/sports/football/01giants.html', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01giants'}
#
# 1729042
# 2006/01/01
# By KAREN CROUSE, Crouse, Karen
# {'taxonomic_classifier': 'Top/News/Sports/Pro Football', 'descriptor': 'Football', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Football', 'dsk': 'Sports Desk', 'print_page_number': '7', 'normalized_byline': 'Crouse, Karen', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01jets'}
#
# 1729043
# 2006/01/01
# By JUDY BATTISTA, Battista, Judy
# {'taxonomic_classifier': 'Top/News/Sports/Pro Football', 'descriptor': 'Football', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Sports', 'publication_month': '1', 'general_descriptor': 'Football', 'dsk': 'Sports Desk', 'print_page_number': '7', 'normalized_byline': 'Battista, Judy', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': '01patriots'}
#
# 1729044
# 2006/01/01
#
# {'types_of_material': 'Caption', 'descriptor': 'Football', 'publication_day_of_month': '1', 'publication_year': '2006', 'publication_month': '1', 'general_descriptor': 'Football', 'dsk': 'Sports Desk', 'print_page_number': '1', 'print_section': '8', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01shaunfloater'}
#
# 1729045
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '11', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': 'l01island-1'}
#
# 1729046
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '11', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': 'l01island-2'}
#
# 1729047
# 2006/01/01
# By LYDIA POLGREEN, Polgreen, Lydia
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Africa/Niger', 'descriptor': 'Economic Conditions and Trends', 'publication_day_of_month': '1', 'normalized_byline': 'Polgreen, Lydia', 'publication_year': '2006', 'online_sections': 'World', 'publication_month': '1', 'general_descriptor': 'Economic Conditions and Trends', 'correction_date': '20060102T000000', 'dsk': 'Foreign Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/international/africa/01nigeria.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'banner': 'CORRECTION APPENDED', 'slug': '01nigeria'}
#
# 1729048
# 2006/01/01
# By GARY RIVLIN, Rivlin, Gary
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/Louisiana', 'descriptor': 'Real Estate', 'publication_day_of_month': '1', 'normalized_byline': 'Rivlin, Gary', 'publication_year': '2006', 'online_sections': 'U.S.', 'publication_month': '1', 'general_descriptor': 'Housing', 'dsk': 'National Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/realestate/01real.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01real'}
#
# 1729049
# 2006/01/01
# By ERIC LICHTBLAU and JAMES RISEN, Risen, James; Lichtblau, Eric
# {'taxonomic_classifier': 'Top/Classifieds/Job Market/Job Categories/Technology, Telecommunications and Internet', 'descriptor': 'Espionage', 'publication_day_of_month': '1', 'normalized_byline': 'Risen, James; Lichtblau, Eric', 'publication_year': '2006', 'online_sections': 'Technology; U.S.', 'publication_month': '1', 'general_descriptor': 'Politics and Government', 'dsk': 'National Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/politics/01spy.html', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01spy'}
#
# 1729050
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/New York/New York City', 'types_of_material': 'Caption', 'descriptor': 'New Year', 'publication_day_of_month': '1', 'publication_year': '2006', 'publication_month': '1', 'general_descriptor': 'Holidays and Special Occasions', 'dsk': 'Metropolitan Desk', 'print_page_number': '1', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01square--floater'}
#
# 1729051
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'Westchester Weekly Desk', 'print_page_number': '11', 'print_section': '14WC', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': 'l01mansion-1'}
#
# 1729052
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'Westchester Weekly Desk', 'print_page_number': '11', 'print_section': '14WC', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': 'l01mansion-2'}
#
# 1729053
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'Westchester Weekly Desk', 'print_page_number': '11', 'print_section': '14WC', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': 'l01mansion-3'}
#
# 1729054
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/New York and Region/Connecticut', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Connecticut Weekly Desk', 'print_page_number': '2', 'print_section': '14CN', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01ctbriefs-1'}
#
# 1729055
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/New York and Region/Connecticut', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Connecticut Weekly Desk', 'print_page_number': '2', 'print_section': '14CN', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01ctbriefs-2'}
#
# 1729056
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/New York and Region/Connecticut', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Connecticut Weekly Desk', 'print_page_number': '2', 'print_section': '14CN', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01ctbriefs-3'}
#
# 1729057
# 2006/01/01
# By JEFF HOLTZ
# {'taxonomic_classifier': 'Top/News/New York and Region/Connecticut', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Connecticut Weekly Desk', 'print_page_number': '2', 'print_section': '14CN', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01ctbriefs-4'}
#
# 1729058
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729059
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729060
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729061
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729062
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729063
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729064
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729065
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729066
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729067
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729068
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729069
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729070
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729071
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729072
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729073
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729074
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729075
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729076
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729077
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729078
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729079
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729080
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729081
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729082
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729083
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729084
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729085
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729086
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729087
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729088
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729089
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729090
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729091
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Death Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729092
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729093
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729094
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729095
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729096
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729097
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729098
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729099
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729100
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729101
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729102
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729103
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729104
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1729105
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Classifieds/Paid Death Notices', 'types_of_material': 'Paid Memorial Notice', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Paid Death Notices', 'publication_month': '1', 'dsk': 'Classified', 'print_page_number': '26', 'print_section': '1', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'dn010106'}
#
# 1728900
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Labor', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Business; Opinion', 'publication_month': '1', 'general_descriptor': 'Labor', 'dsk': 'Money and Business/Financial Desk', 'print_page_number': '7', 'print_section': '3', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01sunbizletters-1'}
#
# 1728901
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Layoffs and Job Reductions', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Business; Opinion', 'publication_month': '1', 'general_descriptor': 'Labor', 'dsk': 'Money and Business/Financial Desk', 'print_page_number': '7', 'print_section': '3', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01sunbizletters-2'}
#
# 1728902
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Executives and Management', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Business; Opinion', 'publication_month': '1', 'general_descriptor': 'Labor', 'dsk': 'Money and Business/Financial Desk', 'print_page_number': '7', 'print_section': '3', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': '01sunbizletters-3'}
#
# 1728903
# 2006/01/01
# By Bill Cunningham
# <p>
# {'taxonomic_classifier': 'Top/Features/Style/Fashion and Style', 'descriptor': 'Parties (Social)', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Style', 'publication_month': '1', 'general_descriptor': 'Parties (Social)', 'dsk': 'Style Desk', 'print_page_number': '7', 'print_section': '9', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01part'}
#
# 1728904
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Corrections', 'types_of_material': 'Correction', 'descriptor': 'Parties (Social)', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Style; Corrections', 'publication_month': '1', 'general_descriptor': 'Holidays and Special Occasions', 'dsk': 'Style Desk', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/fashion/01scxn.html', 'print_section': '9', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': '01scxn'}
#
# 1728905
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'The City Weekly Desk', 'print_page_number': '9', 'print_section': '14', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': 'l01city-1'}
#
# 1728906
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'The City Weekly Desk', 'print_page_number': '9', 'print_section': '14', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': 'l01city-2'}
#
# 1728907
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'The City Weekly Desk', 'print_page_number': '9', 'print_section': '14', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': 'l01city-3'}
#
# 1728908
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'The City Weekly Desk', 'print_page_number': '9', 'print_section': '14', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': 'l01city-4'}
#
# 1728909
# 2006/01/01
# By PETER EDIDIN
# {'taxonomic_classifier': 'Top/Classifieds/Job Market/Job Categories/Media, Entertainment and Publishing', 'descriptor': 'Motion Pictures', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Movies; Week in Review', 'publication_month': '1', 'general_descriptor': 'Motion Pictures', 'correction_date': '20060129T000000', 'dsk': 'Week in Review Desk', 'print_page_number': '10', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01edid.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'banner': 'CORRECTION APPENDED', 'slug': '01edid'}
#
# 1728910
# 2006/01/01
# By DAVID E. SANGER
# {'taxonomic_classifier': 'Top/Features/Week in Review', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Week in Review', 'publication_month': '1', 'dsk': 'Week in Review Desk', 'print_page_number': '2', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01davi'}
#
# 1728911
# 2006/01/01
# By DANIEL GROSS
# {'taxonomic_classifier': 'Top/Classifieds/Job Market/Job Categories/Banking, Finance and Insurance', 'descriptor': 'Stocks and Bonds', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Week in Review', 'publication_month': '1', 'general_descriptor': 'Finances', 'dsk': 'Week in Review Desk', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01gross.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01gross'}
#
# 1728912
# 2006/01/01
# By STEVEN LEE MYERS
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Europe/Belarus', 'descriptor': 'Elections', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Week in Review', 'publication_month': '1', 'general_descriptor': 'Politics and Government', 'dsk': 'Week in Review Desk', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01myer.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01myer'}
#
# 1728913
# 2006/01/01
# By ADAM NAGOURNEY
# {'taxonomic_classifier': 'Top/Classifieds/Job Market/Job Categories/Government, Philanthropy and NGO', 'descriptor': 'Politics and Government', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Week in Review', 'publication_month': '1', 'general_descriptor': 'Politics and Government', 'correction_date': '20060108T000000', 'dsk': 'Week in Review Desk', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01nago.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'banner': 'CORRECTION APPENDED', 'slug': '01nago'}
#
# 1728914
# 2006/01/01
# By MICHAEL SLACKMAN
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Middle East/Syria', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Week in Review', 'publication_month': '1', 'dsk': 'Week in Review Desk', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01slackman.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01slackman'}
#
# 1728915
# 2006/01/01
# By DAVID CARR
# {'taxonomic_classifier': 'Top/Features/Week in Review', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Week in Review', 'publication_month': '1', 'dsk': 'Week in Review Desk', 'print_page_number': '3', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01carr.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01carr'}
#
# 1728916
# 2006/01/01
# By GINA KOLATA
# {'taxonomic_classifier': 'Top/News/Health/Diseases, Conditions, and Health Topics/Genetics and Heredity', 'descriptor': 'Science and Technology', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Technology; Science; Health; Week in Review', 'publication_month': '1', 'general_descriptor': 'Medicine and Health', 'dsk': 'Week in Review Desk', 'print_page_number': '3', 'alternate_url': 'http://www.nytimes.com/2006/01/01/weekinreview/01kolata.html', 'print_section': '4', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01kolata'}
#
# 1728917
# 2006/01/01
# By DAVID POGUE
# ...
#
# 1728747
# 2006/01/01
# By Charles McGrath
# {'taxonomic_classifier': 'Top/Classifieds/Job Market/Job Categories/Media, Entertainment and Publishing', 'descriptor': 'Motion Pictures', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Movies; Arts', 'publication_month': '1', 'general_descriptor': 'Motion Pictures', 'dsk': 'Arts and Leisure Desk', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/movies/01mcgr.html', 'print_section': '2', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01mcgr'}
#
# 1728748
# 2006/01/01
# By ROBERT SIMONSON
# {'taxonomic_classifier': 'Top/Classifieds/Job Market/Job Categories/Music, Theater and Dance', 'descriptor': 'Theater', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Arts; Theater', 'publication_month': '1', 'general_descriptor': 'Theater', 'dsk': 'Arts and Leisure Desk', 'print_page_number': '2', 'alternate_url': 'http://www.nytimes.com/2006/01/01/theater/01simonson.html', 'print_section': '2', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01simonson'}
#
# 1728749
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Corrections', 'types_of_material': 'Correction', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Corrections', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '3', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01cx-1'}
#
# 1728750
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Corrections', 'types_of_material': 'Correction', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Corrections', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '3', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01cx-2'}
#
# 1728751
# 2006/01/01
# By DENNY LEE
# {'taxonomic_classifier': 'Top/Features/Travel/Sunday Travel', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Travel', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '6', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01whatnext'}
#
# 1728752
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Opinion', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '12', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01mail-1'}
#
# 1728753
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Opinion', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '12', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01mail-2'}
#
# 1728754
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Opinion', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '12', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01mail-3'}
#
# 1728755
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Opinion', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '12', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '5', 'slug': '01mail-4'}
#
# 1728756
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Opinion', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '12', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': '01mail-5'}
#
# 1728757
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Opinion', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '12', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': '01mail-6'}
#
# 1728758
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Opinion', 'publication_month': '1', 'dsk': 'Travel Desk', 'print_page_number': '12', 'print_section': '5', 'publication_day_of_week': 'Sunday', 'print_column': '6', 'slug': '01mail-7'}
#
# 1728759
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Figure Skating', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'Ice Skating', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01letters.1-1'}
#
# 1728760
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Figure Skating', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'Ice Skating', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01letters.1-2'}
#
# 1728761
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Activities and Interests/Shopping', 'types_of_material': 'Letter', 'descriptor': 'Retail Stores and Trade', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'Retail Stores and Trade', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01letters.1-3'}
#
# 1728762
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Technology', 'types_of_material': 'Letter', 'descriptor': 'Athletics and Sports', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Technology; Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'History', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01letters.1-4'}
#
# 1728763
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Urine', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'Medicine and Health', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01letters.1-5'}
#
# 1728764
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Condoms', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'Crime and Criminals', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '2', 'slug': '01letters.1-6'}
#
# 1728765
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Technology', 'types_of_material': 'Letter', 'descriptor': 'Inventions and Patents', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Technology; Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'Inventions and Patents', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01letters.1-7'}
#
# 1728766
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'descriptor': 'Transcendental Meditation', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine; Opinion', 'publication_month': '1', 'general_descriptor': 'Medicine and Health', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01letters.1-8'}
#
# 1728767
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Opinion/Opinion', 'types_of_material': 'Letter', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine; Opinion', 'publication_month': '1', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01letters.1-9'}
#
# 1728768
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Corrections', 'types_of_material': 'Correction', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Corrections; Magazine', 'publication_month': '1', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01letters.1-10'}
#
# 1728769
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Corrections', 'types_of_material': 'Correction', 'descriptor': 'Correction Stories', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Corrections; Magazine', 'publication_month': '1', 'general_descriptor': 'Comic Books and Strips', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01letters.1-11'}
#
# 1728770
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/Corrections', 'types_of_material': 'Correction', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Corrections; Magazine', 'publication_month': '1', 'dsk': 'Magazine', 'print_page_number': '10', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '4', 'slug': '01letters.1-12'}
#
# 1728771
# 2006/01/01
# By Amanda Hesser, Hesser, Amanda
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/Asia/Japan', 'descriptor': 'Cooking and Cookbooks', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'Magazine', 'publication_month': '1', 'general_descriptor': 'Cooking and Cookbooks', 'dsk': 'Magazine', 'print_page_number': '54', 'normalized_byline': 'Hesser, Amanda', 'print_section': '6', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01food-1'}
#
# 1728772
# 2006/01/01
# By MARCELLE S. FISCHLER
# {'taxonomic_classifier': 'Top/News/New York and Region/Long Island', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '4', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '3', 'slug': '01lijour'}
#
# 1728773
# 2006/01/01
# By BRIAN WISE
# {'taxonomic_classifier': 'Top/News/New York and Region/Long Island', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '8', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01lifish'}
#
# 1728774
# 2006/01/01
# By LINDA SASLOW
# {'taxonomic_classifier': 'Top/News/New York and Region/Long Island', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '8', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01liflute'}
#
# 1728775
# 2006/01/01
# By KATHRYN SHATTUCK
# {'taxonomic_classifier': 'Top/News/New York and Region/Long Island', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '8', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01lifoot'}
#
# 1728776
# 2006/01/01
# By VIVIAN S. TOY
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/New York', 'descriptor': 'Teachers and School Employees', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'general_descriptor': 'Education and Schools', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '1', 'alternate_url': 'http://www.nytimes.com/2006/01/01/nyregion/nyregionspecial2/01lielmo.html', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01lielmo'}
#
# 1728777
# 2006/01/01
# By Leslie Mastin
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/New York/New York City', 'types_of_material': 'Op-Ed', 'descriptor': 'Handicapped', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'general_descriptor': 'Handicapped', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '11', 'alternate_url': 'http://www.nytimes.com/2006/01/01/opinion/nyregionopinions/01LImastin.html', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01LImastin'}
#
# 1728778
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/New York', 'types_of_material': 'Editorial', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '11', 'alternate_url': 'http://www.nytimes.com/2006/01/01/opinion/nyregionopinions/LI_Transit.html', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'LI--Transit'}
#
# 1728779
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/New York', 'types_of_material': 'Editorial', 'descriptor': 'Environment', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region; Opinion', 'publication_month': '1', 'general_descriptor': 'Environment', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '11', 'alternate_url': 'http://www.nytimes.com/2006/01/01/opinion/nyregionopinions/LIoceans.html', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': 'LIoceans'}
#
# 1728780
# 2006/01/01
#
# {'taxonomic_classifier': 'Top/News/New York and Region/Long Island', 'types_of_material': 'Summary', 'descriptor': 'NO INDEX TERMS FROM NYTIMES', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '1', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01linitsum'}
#
# 1728781
# 2006/01/01
# By JULIA C. MEAD
# {'taxonomic_classifier': 'Top/Features/Travel/Guides/Destinations/North America/United States/New York', 'descriptor': 'Housing', 'publication_day_of_month': '1', 'publication_year': '2006', 'online_sections': 'New York and Region', 'publication_month': '1', 'general_descriptor': 'Housing', 'dsk': 'Long Island Weekly Desk', 'print_page_number': '3', 'alternate_url': 'http://www.nytimes.com/2006/01/01/nyregion/nyregionspecial2/01lieast.html', 'print_section': '14LI', 'publication_day_of_week': 'Sunday', 'print_column': '1', 'slug': '01lieast'}

# %%
d = {}
d['a'] = 3
d['b'] = 5
print d
# Out:
# {'a': 3, 'b': 5}

# %%
build body/<year>/<month>/<day>/<guid>.txt
build headline/<year>/<month>/<day>/<guid>.txt
build lead/<year>/<month>/<day>/<guid>.txt

build csv: 
    <doc-id => id-string>/ ======> by fname
    <meta name pluication_year => content>/
    <meta name pluication_month => content>/
    <meta name publication_day_of_month => content>/ ===> by dirname as pdate
    <meta name feature_page => content>/
    <meta name online_sections => content>/
    <meta name online_column => content>/
    <meta name dsk => content>/
    <classifier type descriptor => text>/
    <classifier type names => text>/
    <classifier type types_of_material => text>/
    <classifier type taxonomic_classifier => text>/
    <classifier type general_descriptor => text>/
    <byline class normalized_byline => text>/
    <org => text>/
    
    
    

column_name

# %%
<?xml version="1.0" encoding="UTF-8"?>
<!DOCTYPE nitf SYSTEM "http://www.nitf.org/IPTC/NITF/3.3/specification/dtd/nitf-3-3.dtd">
<nitf change.date="June 10, 2005" change.time="19:30" version="-//IPTC//DTD NITF 3.3//EN">
<head>
<title>
! Sorry, Ma'am, No Listing for 'enry 'iggins; Voice Recognition
! Is Improving, but Don't Stop the Elocution Lessons
</title>
! <meta content="02ess" name="slug"/>
<meta content="26" name="publication_day_of_month"/>
<meta content="6" name="publication_month"/>
<meta content="1995" name="publication_year"/>
<meta content="Monday" name="publication_day_of_week"/>
<meta content="Business/Financial Desk" name="dsk"/>
<meta content="1" name="print_page_number"/>
<meta content="D" name="print_section"/>
<meta content="5" name="print_column"/>
<meta content="Technology; Business" name="online_sections"/>
<meta content="http://www.nytimes.com/1995/06/27/02ess.html" name="alternate_url"/>
<meta content="Correction Appened" name="banner"/>
<meta content="19950627T000000" name="correction_date"/>
<meta content="EDUCATION" name="feature_page"/>
<meta content="columnName" name="Education Column"/>
<meta content="seriesName" name="Education Series"/>
<docdata>
<doc-id id-string="! "/>
<doc.copyright holder="The New York Times" year="1995"/>
! <series series.name="Sorry, Ma'am, No Listing for 'enry 'iggins"/>
<identified-content>
! ! <classifier class="indexing_service" type="biographical_categories">Books and Magazines</classifier>
<classifier class="indexing_service" type="descriptor">DATA PROCESSING (COMPUTERS)</classifier>
! ! <location class="indexing_service">NEW YORK, NY</location>
<classifier class="indexing_service" type="names">MCLEMORE, CYNTHIA</classifier>
<org class="indexing_service">LINGUISTIC DATA CONSORTIUM</org>
<person class="indexing_service">KAUFMAN, MICHAEL T</person>
<object.title class="indexing_service">NEW YORK TIMES CORPUS (DATA)</object.title>
<classifier class="online_producer" type="types_of_material">Article</classifier>
<classifier class="online_producer" type="taxonomic_classifier">Top/News/Technology</classifier>
! ! <classifier class="online_producer" type="descriptor">Computers And The Internet</classifier>
<classifier class="online_producer" type="general_descriptor">Research</classifier>
<location class="online_producer">Philadelphia (Penna)</location>
<org class="online_producer">Linguistic Data Consortium (LDC)</org>
<person class="online_producer">Lomax, Alan</person>
<object.title class="online_producer">New York Times Corpus (DATA)</object.title>
</identified-content>
</docdata>
<pubdata date.publication="19950626T000000"
! ! ex-ref="http://query.nytimes.com/gst/fullpage.html?res=990CEFDC1139F935A15755C0A963958260"
! ! item-length="1590"
! ! name="The New York Times"
! ! unit-of-measure="word"
/>
</head>
<body>
<body.head>
<hedline>
<hl1>Voice Recognition Is Improving, but Don't Stop the Elocution Lessons</hl1>
<hl2 class="online_headline">Sorry, Ma'am, No Listing for 'enry 'iggins</hl2>
</hedline>
<byline class="print_byline">By MICHAEL T. KAUFMAN</byline>
<byline class="normalized_byline">KAUFMAN, MICHAEL T</byline>
<dateline>Philadelphia, June. 25</dateline>
<abstract>
<p>
! The Linguistic Data Consortium, a research cooperative,
! has released several large collections of data to spur advances
! in speech recognition.
</p>
</abstract>
</body.head>
<body.content>
<block class="lead_paragraph">
<p>What if I say "tomahto" and you say "tomayto?"</p>
</block>
<block class="online_lead_paragraph">
<p>What if I say "tomahto" and you say "tomayto?"</p>
</block>
<block class="full_text">
<p>As voice-recognition technologies are making their way from...</p>
</block>
! <block class="correction_text">
<p>Yesterday's article incorrectly stated...</p>
</block>
</body.content>
! <body.end>
<tagline class="author_info">
! Michael T. Kaufman spent close to forty years at The New York
! Times as a reporter.
</tagline>
</body.end>
</body>
</nitf>

# %%
<?xml version="1.0" encoding="UTF-8"?>
<!DOCTYPE nitf SYSTEM "http://www.nitf.org/IPTC/NITF/3.3/specification/dtd/nitf-3-3.dtd">
<nitf change.date="June 10, 2005" change.time="19:30" version="-//IPTC//DTD NITF 3.3//EN">
  <head>
    <title>Paid Notice: Deaths  FARRELL, PAUL V.</title>
    <meta content="DN080897" name="slug"/>
    <meta content="8" name="publication_day_of_month"/>
    <meta content="8" name="publication_month"/>
    <meta content="1997" name="publication_year"/>
    <meta content="Friday" name="publication_day_of_week"/>
    <meta content="Classified" name="dsk"/>
    <meta content="6" name="print_page_number"/>
    <meta content="B" name="print_section"/>
    <meta content="3" name="print_column"/>
    <meta content="Paid Death Notices" name="online_sections"/>
    <docdata>
      <doc-id id-string="949028"/>
      <doc.copyright holder="The New York Times" year="1997"/>
      <identified-content>
        <person class="indexing_service">FARRELL, PAUL V.</person>
        <classifier class="online_producer" type="types_of_material">Paid Death Notice</classifier>
        <classifier class="online_producer" type="taxonomic_classifier">Top/Classifieds/Paid Death Notices</classifier>
      </identified-content>
    </docdata>
    <pubdata date.publication="19970808T000000" ex-ref="http://query.nytimes.com/gst/fullpage.html?res=9B03E0D7173CF93BA3575BC0A961958260" item-length="8" name="The New York Times" unit-of-measure="word"/>
  </head>
  <body>
    <body.head>
      <hedline>
        <hl1>Paid Notice: Deaths  FARRELL, PAUL V.</hl1>
      </hedline>
    </body.head>
    <body.content>
      <block class="lead_paragraph">
        <p>FARRELL-Paul V. You were the best. Mike Stimson</p>
      </block>
      <block class="full_text">
        <p>FARRELL-Paul V. You were the best. Mike Stimson</p>
      </block>
    </body.content>
  </body>
</nitf>
